# %% [markdown]
# # Segmentating and Clustering Neighborhoods in Chennai

# %% [markdown]
# ### Suraj Eswaran

# %% [markdown]
# # Introduction

# %% [markdown]
# **Chennai** is the capital city of **Tamil Nadu** in India.Located on the **Coromandel coast of the Bay of Bengal**,Chennai enjoys commercial,cultural and educational center in South India.That is why,Chennai is known as the **Cultural Capital of South India**.Over the recent years,**Chennai** is recognized as the **largest exporter of services for IT and BPO**.The Chennai Metropolitan Area is one of the largest municipal economies of India. Chennai is nicknamed **"The Detroit of India"**,with more than **one-third of India's automobile industry** being based in the city.Home to the Tamil film industry,Chennai is also known as a **major film production centre**.Chennai is one of the **100 Indian cities** to be developed as a smart city under the Smart Cities Mission.Chennai hosts cultural events in its vicinity.The **Madras Music Session** is one of them.The classical dance form of Tamilians is **Bharatanatyam**.**Kollywood** is the Tamil film industry located in the city that has great movies made over the years.

# %% [markdown]
# <img src="https://c0.wallpaperflare.com/preview/403/319/581/chennai-india-chennai-lighthouse-marina.jpg">

# %% [markdown]
# **Chennai** is located at **13.04°N 80.17°E** on the southeast coast of India and in the northeast corner of Tamil Nadu.It is located on a flat coastal plain known as the **Eastern Coastal Plains**.The city has an average elevation of **6 metres (20 ft)**,its highest point being **60 m (200 ft)**.Chennai features a **tropical wet and dry climate**.Chennai lies on the **thermal equator** and is also coastal, which prevents extreme variation in seasonal temperature.For most of the year,the weather is **hot and humid**.The hottest part of the year is **late May** and **early June**, known locally as **Agni Nakshatram ("fiery star")** or as **Kathiri Veyyil**,with maximum temperatures around **100–108 °F**.The coolest part of the year is **January**,with minimum temperatures around **64–68 °F**.The lowest temperature recorded is **57.0 °F** and highest **113 °F**.Chennai is well connected by road, rail, air, and sea.It has an **international airport** and **seaport**.Within the city a network of **bus services** and **auto-rickshaws** are common modes of transport.The historic town of **Mamallapuram** with its shore temple,about **37 miles (60 km)** south of Chennai,is a popular tourist destination.

# %% [markdown]
# <img src="https://www.tripsavvy.com/thmb/xr_UdfffyqgA0xH4NWaCfsHWUgk=/1989x1326/filters:fill(auto,1)/GettyImages-579760012-b78004a355354623924eda63842ac3a9.jpg">

# %% [markdown]
# # Problem Description

# %% [markdown]
# **Chennai** has witnessed a dramatic growth over the couple of years.Even though it has various diversity of choices,it is necessary to know about diversity of the business problem which we will discuss in the later sections in order to understand the choice of food that chennaiites prefer to eat,which can help us open a restaurant in chennai.**Starting a restaurant** deals with various factors before **investors** take place in this business.So,my project is all about **analyzing various restaurants in chennai** and **preferred kind of restuarant to start at chennai**.

# %% [markdown]
# <img src="https://chaibisket.com/wp-content/uploads/2018/09/superstar-pizza-thillai-nagar-trichy-home-delivery-restaurants-29q2l-e1538303628391.jpg">

# %% [markdown]
# # Background Description

# %% [markdown]
# Even though restaurant food is considered to be unhealthy,food has been the most popular aspect in Chennai.**Idly Sambar** is one such south indian food which is served at breakfast,tiffin and dinner.Apart from this,there are various kinds of restaurants that are also popular in Chennai.**Burmese** and **Gujarati** restaurants are so popular in Chennai.Places like **Triplicane** where we can witness different kinds of restaurants.One side,it has **Nawabi style restaurant** and other side it has **south indian ratna cafe**.We can find even **Kerala based restaurant** where **malabar parottas** is famous.**Mylapore** is home to many bhavans that are temples of Tamilian and **Chettinad tiffin**.**Adyar Ananda Bhavan** and **Saravana Bhavan** tower over the Kapali Temple tank,their neon light shimmering across its surface by night.But it is places like **KPGM Mess** and **Kaiyendi Bhavan** you should opt for to get a taste of real tiffin without the spin.Another well-known street food place in Chennai is **Anna Nagar**.Now,this place is famous for **local street food joints** that cater to the needs of people from different communities.Moreover,you will find a unique flavor in all food varieties.In addition,you can find **Jigarthanda**,one of the popular drinks in Chennai and delicious south Indian dishes.For **samosa**,the best area to explore is **Mount Road** as there are variety of **samosas** with **lassis**.**Burma Bazaar** is one of the famous areas in Chennai which serves **Burmese Food**.**Atho** which is popular street food in Chennai.It is made of **noodles** served with **vegetables**.Not only this there are many more Burmese dishes like **Bejo**, **Mohinga**, **egg noodles**, etc.**Bhajjis** is one of the loved food in Chennai as it is served with **chutney** which would boost your mood.

# %% [markdown]
# <img src="https://theculturetrip.com/wp-content/uploads/2017/11/the_bajji_maker-683x1024.jpg">

# %% [markdown]
# # Methodology

# %% [markdown]
# I utilized the concept of web scrapping from list of areas of chennai.Along with that,we have used public libraries and API's like **FourSquare API**.**Web Scrapping** is a way of exporting a data from the website as we don't find all the data in CSV format.When we scrape a web,we write code that sends a request to the server that’s hosting the page we specified.
# Steps involves:
# <ol>
# <li>Data is collected from <strong>Wikipedia</strong> and performed data cleaning and processsed to a dataframe.</li>
# <li>For finding the <strong>latitude</strong> and <strong>longitude</strong>,we have utilized the <strong>Geopy</strong>.</li>
# <li>Perform <strong>one hot encoding</strong> and found <strong>10 common venues</strong> at various areas.</li>
# <li>Utilized <strong>K-Nearest Cluster</strong> to find the best restaurant to start at chennai.</li>
# </ol>

# %% [markdown]
# # 1. Import the Libraries

# %% [markdown]
# We have utilized the several python liberies as it contains different kinds of components.Liberies contains the core dependencies of a language with some built-in functions and exceptions with the help of import.It is written in C and takes care of functionality with core modules.
# Now we will see the list of liberies that we have used for this project:
# <ol>
# <li><strong>Pandas</strong>:Pandas is the most important library in data science.It offers <strong>data structures and tools for effective data cleaning, manipulation, and analysis</strong>. It provides tools to work with different types of data.The primary instrument of Pandas is that it is a <strong>low-dimensional table</strong> consisting of columns and rows.The table is called a <strong>“DataFrame”</strong> and is designed to provide easy indexing so you can work with your data.</li>
# <li><strong>Numpy</strong>:It is based on <strong>arrays</strong> as it enables you to apply mathematical function to these arrays.It contains <strong>math functions</strong> and <strong>scientific computing packages</strong>.</li>
# <li><strong>Requests</strong>:It lets you send <strong>HTTP/1.1 requests and form data</strong>.</li>
# <li><strong>JSON</strong>:It is a <strong>built-in package</strong> which can be used to work with <strong>JSON data</strong>.</li>
# <li><strong>Matplotlib</strong>:It is a <strong>numerical plotting library</strong> which helps in <strong>data analyzing</strong>.</li>
# <li><strong>Scikit-learn</strong>:It is a <strong>machine learning based library</strong>.</li>
# <li><strong>BeautifulSoup</strong>:It is a library which is used for <strong>parsing HTML and XML documents</strong>.</li>
# <li><strong>Folium</strong>:It is a library used for <strong>visualizing geospatial data</strong>.</li>
# <li><strong>lxml</strong>:It is useful for allowing the <strong>easy handling of the HTML and XML files</strong> and can be useful for web scrapping.</li>
# </ol>

# %% [markdown]
# ### Version of Pandas

# %% [markdown]
# For this project,we have utilized version **1.2.1** as it supports beautifulsoup and lxml libraries and converts the data to pandas DataFrame.Below,we have printed the version of the pandas.

# %%
import pandas as pd 
print(pd.__version__)
# !pip install pandas==1.2.1
print(pd.__version__)
# Out:
# 1.2.1
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/envs/Python-3.7-main/include/python3.7m/UNKNOWN
# sysconfig: /opt/conda/envs/Python-3.7-main/include/python3.7m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# ...
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /opt/conda/envs/Python-3.7-main/include/python3.7m/UNKNOWN
# sysconfig: /opt/conda/envs/Python-3.7-main/include/python3.7m
# WARNING: Additional context:
# user = False
# home = None
# root = None
# prefix = None
# 1.2.1

# %% [markdown]
# ### Usage of other Libraries

# %% [markdown]
# We have utilized all the libraries that has been listed above as followed.

# %%
import numpy as np # library to handle data in a vectorized manner
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### Installation of Folium Library

# %% [markdown]
# We don't have folium version **0.5.0** in our notebook,so we are installing the library for visualizing maps in Chennai.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
print('Libraries imported.')
# Out:
# ...
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=2155
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=2155
#   - conda-forge/linux-64::pytorch==1.8.0=cpu_py37ha70c682_1
# done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### Usage of Web Scrapping Libraries

# %%
from bs4 import BeautifulSoup
import lxml
from IPython.display import display_html

# %% [markdown]
# # 2. Download and Explore Dataset

# %% [markdown]
# For this project,I have take list of areas of chennai from Wikipedia which consist of 15 zones with 200 wards.For obtaining the venue details,we have utilized the FourSquare API.
#
# <ol>
# <li>https://en.wikipedia.org/wiki/Areas_of_Chennai</li>
# <li>https://foursquare.com</li>
# </ol>

# %% [markdown]
# ### Usage of data from wikipedia

# %%
url="https://en.wikipedia.org/wiki/Areas_of_Chennai"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')
#chennai_table = soup.find('table', class_='wikitable')
#chennai_table
#print(soup.title)
chennai_table=str(soup.table)
display_html(chennai_table,raw=True)
# Out:
# <table class="wikitable">
# <tbody><tr>
# <th>Location
# </th></tr>
# <tr>
# <td><a href="/wiki/Adambakkam" title="Adambakkam">Adambakkam</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Adyar,_Chennai" title="Adyar, Chennai">Adyar</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Alandur" title="Alandur">Alandur</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Alapakkam" title="Alapakkam">Alapakkam</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Alwarpet" title="Alwarpet">Alwarpet</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Alwarthirunagar" title="Alwarthirunagar">Alwarthirunagar</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Ambattur" title="Ambattur">Ambattur</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Aminjikarai" title="Aminjikarai">Aminjikarai</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Anna_Nagar" title="Anna Nagar">Anna Nagar</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Annanur" title="Annanur">Annanur</a>
# </td></tr>
# <tr>
# ...

# %% [markdown]
# # 3.Transform the data into a pandas dataframe

# %%
import pandas as pd
dfs = pd.read_html(chennai_table)
df=dfs[0]
df
# Out:
#                       Location
# 0                   Adambakkam
# 1                        Adyar
# 2                      Alandur
# 3                    Alapakkam
# 4                     Alwarpet
# 5              Alwarthirunagar
# 6                     Ambattur
# 7                  Aminjikarai
# 8                   Anna Nagar
# 9                      Annanur
# 10                  Arumbakkam
# 11                 Ashok Nagar
# 12                       Avadi
# 13                  Ayanavaram
# 14                Besant Nagar
# 15                Basin Bridge
# 16                     Chepauk
# 17                     Chetput
# 18                Chintadripet
# 19                Chitlapakkam
# 20                     Choolai
# 21                 Choolaimedu
# 22                    Chrompet
# 23                      Egmore
# 24               Ekkaduthangal
# 25                    Eranavur
# 26                      Ennore
# 27            Foreshore Estate
# 28             Fort St. George
# ...

# %% [markdown]
# # 4.Finding Geocode of Chennai and utilizing geopy with pandas Dataframe

# %%
from geopy.extra.rate_limiter import RateLimiter
geolocator = Nominatim(user_agent="chennai_explorer")
address='Chennai, Tamil Nadu'
location = geolocator.geocode(address)
geocode=RateLimiter(geolocator.geocode,min_delay_seconds=1)
df['locate']=df['Location'].apply(geocode)
df['point']=df['locate'].apply(lambda loc:tuple(loc.point) if loc else None)
df
# Out:
#                       Location  \
# 0                   Adambakkam
# 1                        Adyar
# 2                      Alandur
# 3                    Alapakkam
# 4                     Alwarpet
# 5              Alwarthirunagar
# 6                     Ambattur
# 7                  Aminjikarai
# 8                   Anna Nagar
# 9                      Annanur
# 10                  Arumbakkam
# 11                 Ashok Nagar
# 12                       Avadi
# 13                  Ayanavaram
# 14                Besant Nagar
# 15                Basin Bridge
# 16                     Chepauk
# 17                     Chetput
# 18                Chintadripet
# 19                Chitlapakkam
# 20                     Choolai
# 21                 Choolaimedu
# 22                    Chrompet
# 23                      Egmore
# 24               Ekkaduthangal
# 25                    Eranavur
# 26                      Ennore
# 27            Foreshore Estate
# 28             Fort St. George
# ...

# %% [markdown]
# # 5. Dividing the point to latitude, longitude and altitude

# %%
df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)
df1=df.drop(columns=['locate','point'])
df1
# Out:
#                       Location   latitude   longitude  altitude
# 0                   Adambakkam  12.982221   80.209121       0.0
# 1                        Adyar  13.006450   80.257779       0.0
# 2                      Alandur  13.002822   80.171919       0.0
# 3                    Alapakkam  13.049901   80.165435       0.0
# 4                     Alwarpet  13.033860   80.254549       0.0
# 5              Alwarthirunagar  13.047486   80.183669       0.0
# 6                     Ambattur  13.112886   80.159862       0.0
# 7                  Aminjikarai  13.072140   80.220545       0.0
# 8                   Anna Nagar  13.087200   80.216442       0.0
# 9                      Annanur  13.116356   80.126913       0.0
# 10                  Arumbakkam  13.074371   80.208131       0.0
# 11                 Ashok Nagar  13.040073   80.215925       0.0
# 12                       Avadi  13.125476   80.094090       0.0
# 13                  Ayanavaram  13.094616   80.235410       0.0
# ...

# %% [markdown]
# # 6. Cleaning the data manually

# %%
#location='Ekkaduthangal'
#df1.replace(np.nan, 0)
#df1.at['24', 'latitude'] = '13.0239'
#df1
#df=df.drop(df.index[24,25,40,42,45,114,134,144,145,148,157])
#df1['latitude'] = df1['latitude'].replace(np.nan, 0)
#df1['longitude'] = df1['longitude'].replace(np.nan, 0)

df1['altitude'] = df1['altitude'].replace(np.nan, 0)
df1.loc[(df1.Location == 'Ekkaduthangal'),'latitude']='13.0239'
df1.loc[(df1.Location == 'Ekkaduthangal'),'longitude']='80.2001'

df1.loc[(df1.Location == 'Eranavur'),'latitude']='13.1896'
df1.loc[(df1.Location == 'Eranavur'),'longitude']='80.3039'

df1.loc[(df1.Location == 'ICF'),'latitude']='13.0981'
df1.loc[(df1.Location == 'ICF'),'longitude']='80.2195'

df1.loc[(df1.Location == 'Kattivakkam'),'latitude']='13.2161'
df1.loc[(df1.Location == 'Kattivakkam'),'longitude']='80.3182'

df1.loc[(df1.Location == 'Kazhipattur'),'latitude']='12.8236'
df1.loc[(df1.Location == 'Kazhipattur'),'longitude']='80.2310'

df1.loc[(df1.Location == 'Mannady'),'latitude']='13.0928'
df1.loc[(df1.Location == 'Mannady'),'longitude']='80.2893'

df1.loc[(df1.Location == 'Mount Road'),'latitude']='13.0603'
df1.loc[(df1.Location == 'Mount Road'),'longitude']='80.2590'

df1.loc[(df1.Location == 'Purasaiwalkam'),'latitude']='13.0902'
df1.loc[(df1.Location == 'Purasaiwalkam'),'longitude']='80.2543'

df1.loc[(df1.Location == 'Surapet'),'latitude']='13.1454'
df1.loc[(df1.Location == 'Surapet'),'longitude']='80.1838'

df1.loc[(df1.Location == 'Thirumangalam'),'latitude']='13.0835'
df1.loc[(df1.Location == 'Thirumangalam'),'longitude']='80.1945'

df1.loc[(df1.Location == 'Tiruverkadu'),'latitude']='13.0734'
df1.loc[(df1.Location == 'Tiruverkadu'),'longitude']='80.1269'

df1.loc[(df1.Location == 'Thiruvotriyur'),'latitude']='13.1643'
df1.loc[(df1.Location == 'Thiruvotriyur'),'longitude']='80.3001'

df1.loc[(df1.Location == 'Tiruvallikeni'),'latitude']='13.0588'
df1.loc[(df1.Location == 'Tiruvallikeni'),'longitude']='80.2756'

df1.loc[(df1.Location == 'Velappanchavadi'),'latitude']='13.0585'
df1.loc[(df1.Location == 'Velappanchavadi'),'longitude']='80.1355'

df1.loc[(df1.Location == 'George Town'),'latitude']='13.0969'
df1.loc[(df1.Location == 'George Town'),'longitude']='80.2865'

df1
# Out:
#                       Location   latitude  longitude  altitude
# 0                   Adambakkam  12.982221  80.209121       0.0
# 1                        Adyar   13.00645  80.257779       0.0
# 2                      Alandur  13.002822  80.171919       0.0
# 3                    Alapakkam  13.049901  80.165435       0.0
# 4                     Alwarpet   13.03386  80.254549       0.0
# 5              Alwarthirunagar  13.047486  80.183669       0.0
# 6                     Ambattur  13.112886  80.159862       0.0
# 7                  Aminjikarai   13.07214  80.220545       0.0
# 8                   Anna Nagar    13.0872  80.216442       0.0
# 9                      Annanur  13.116356  80.126913       0.0
# 10                  Arumbakkam  13.074371  80.208131       0.0
# 11                 Ashok Nagar  13.040073  80.215925       0.0
# 12                       Avadi  13.125476   80.09409       0.0
# 13                  Ayanavaram  13.094616   80.23541       0.0
# ...

# %% [markdown]
# # 7. Converting the latitude and longitude data to numeric

# %%
#df1['latitude'] = df1['latitude'].astype(int)
df1['latitude'] = pd.to_numeric(df1['latitude'])
df1['longitude'] = pd.to_numeric(df1['longitude'])
df1
# Out:
#                       Location   latitude  longitude  altitude
# 0                   Adambakkam  12.982221  80.209121       0.0
# 1                        Adyar  13.006450  80.257779       0.0
# 2                      Alandur  13.002822  80.171919       0.0
# 3                    Alapakkam  13.049901  80.165435       0.0
# 4                     Alwarpet  13.033860  80.254549       0.0
# 5              Alwarthirunagar  13.047486  80.183669       0.0
# 6                     Ambattur  13.112886  80.159862       0.0
# 7                  Aminjikarai  13.072140  80.220545       0.0
# 8                   Anna Nagar  13.087200  80.216442       0.0
# 9                      Annanur  13.116356  80.126913       0.0
# 10                  Arumbakkam  13.074371  80.208131       0.0
# 11                 Ashok Nagar  13.040073  80.215925       0.0
# 12                       Avadi  13.125476  80.094090       0.0
# 13                  Ayanavaram  13.094616  80.235410       0.0
# ...

# %% [markdown]
# # 8. Use geopy library to get the latitude and longitude values of Chennai

# %%
from geopy.geocoders import Nominatim
address='Chennai, Tamil Nadu'
geolocator = Nominatim(user_agent="chennai_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Chennai are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Chennai are 13.0836939, 80.270186.

# %% [markdown]
# # 9. Create a map of Chennai with neighborhoods superimposed on top

# %%
map_chennai= folium.Map(location=[13.0836939,80.270186], zoom_start=10)

for lat, lng, loc in zip(df1['latitude'],df1['longitude'], df1['Location']):
    label = '{}'.format(loc)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.7,
        parse_html=False).add_to(map_chennai)  
    
map_chennai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# # 10. Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'RCI2LJCNCNGYLRIOPU2MSCHC3ZGBSKVPLF5FRG12DA1LNIGL' # your Foursquare ID
CLIENT_SECRET = 'D254LXL03DB0ZGUI3ADD32ELMIX4DBMVYX5Q2V1DH2LCM1Y4' # your Foursquare Secret
ACCESS_TOKEN = 'UXC23PT1T1VQQMHIBYNMKY2YYFO3WJEMCWM1HQ3P5MPK4S3S' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RCI2LJCNCNGYLRIOPU2MSCHC3ZGBSKVPLF5FRG12DA1LNIGL
# CLIENT_SECRET:D254LXL03DB0ZGUI3ADD32ELMIX4DBMVYX5Q2V1DH2LCM1Y4

# %% [markdown]
# # 11. Exploring the first neighborhood in our dataframe

# %%
df1['Location'].iloc[0]
# Out:
# 'Adambakkam'

# %% [markdown]
# # 12. Get the neighborhood's latitude and longitude value

# %%
nei_lat=df1['latitude'].iloc[23]
nei_lon=df1['longitude'].iloc[23]
nei_name=df1['Location'].iloc[23]

# %% [markdown]
# # 13. Finding the top 100 venues within a radius of 500 meters

# %%
radius = 500
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, nei_lat, nei_lon, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=RCI2LJCNCNGYLRIOPU2MSCHC3ZGBSKVPLF5FRG12DA1LNIGL&client_secret=D254LXL03DB0ZGUI3ADD32ELMIX4DBMVYX5Q2V1DH2LCM1Y4&ll=13.0728321,80.2576906&v=20180604&radius=500&limit=100'

# %%
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60846ce9839dd92513b3b236'},
#  'response': {'headerLocation': 'Egmore',
#   'headerFullLocation': 'Egmore, Chennai',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 15,
#   'suggestedBounds': {'ne': {'lat': 13.077332104500003,
#     'lng': 80.26230170702087},
#    'sw': {'lat': 13.068332095499995, 'lng': 80.25307949297914}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d51578d3626a093076323bd',
#        'name': 'Flower Drum',
#        'location': {'address': 'Prince Plaza, Pantheon Road',
#         'lat': 13.07143864073082,
#         'lng': 80.25928058671603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 13.07143864073082,
#           'lng': 80.25928058671603}],
# ...

# %% [markdown]
# # 14. Utilize the get_category_type function from the Foursquare lab

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# # 15. Clean the json and structure it into a pandas dataframe

# %%
#assign relevant part of JSON to venues
venues=results['response']['groups'][0]['items']
#venues = results['response']['groups']

# tranforms venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()

filtered_columns = ['venue.name', 'venue.categories','venue.location.lat','venue.location.lng'] 
dataframe_filtered = dataframe.loc[:, filtered_columns]
#dataframe_filtered

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                            name          categories        lat        lng
# 0                   Flower Drum     Thai Restaurant  13.071439  80.259281
# 1                 Sandwich Shop      Sandwich Place  13.069000  80.257288
# 2   Madras Hotel Ashoka Chennai               Motel  13.072523  80.260682
# 3          Icarus Punjabi Dabha   Indian Restaurant  13.069322  80.257016
# 4               Cafe Coffee Day         Coffee Shop  13.068807  80.257384
# 5      Government Museum Egmore              Museum  13.069924  80.256937
# 6                       Mathsya   Indian Restaurant  13.075042  80.257878
# 7     Fruit shop on greams road      Farmers Market  13.074158  80.262100
# 8                Museum Theatre             Theater  13.070470  80.257252
# ...

# %% [markdown]
# # 16. Explore the Neighborhoods

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# # 17. Run the getNearbyVenues function on each neighborhood

# %%
venues_chennai= getNearbyVenues(names=df1['Location'],
                                   latitudes=df1['latitude'],
                                   longitudes=df1['longitude']
                                  )
# Out:
# Adambakkam
# Adyar
# Alandur
# Alapakkam
# Alwarpet
# Alwarthirunagar
# Ambattur
# Aminjikarai
# Anna Nagar
# Annanur
# Arumbakkam
# Ashok Nagar
# Avadi
# Ayanavaram
# Besant Nagar
# Basin Bridge
# Chepauk
# Chetput
# Chintadripet
# Chitlapakkam
# Choolai
# Choolaimedu
# Chrompet
# Egmore
# Ekkaduthangal
# Eranavur
# Ennore
# Foreshore Estate
# Fort St. George
# George Town
# Gopalapuram
# Government Estate
# Guindy
# Gerugambakkam
# IIT Madras
# Injambakkam
# ICF
# Iyyapanthangal
# Jafferkhanpet
# Karapakkam
# Kattivakkam
# Kattupakkam
# Kazhipattur
# K.K. Nagar
# Keelkattalai
# Kattivakkam
# Kilpauk
# Kodambakkam
# Kodungaiyur
# Kolathur
# Korattur
# Korukkupet
# Kottivakkam
# Kotturpuram
# Kottur
# Kovilambakkam
# Koyambedu
# Kundrathur
# Madhavaram
# Madhavaram Milk Colony
# Madipakkam
# Madambakkam
# Maduravoyal
# Manali
# Manali New Town
# Manapakkam
# Mandaveli
# Mangadu
# Mannady
# Mathur
# Medavakkam
# Meenambakkam
# MGR Nagar
# Minjur
# Mogappair
# MKB Nagar
# Mount Road
# ...

# %% [markdown]
# # 18. Number of unique categories returned for each neighborhood in Chennai

# %%
venues_chennai.groupby('Neighbourhood')
print('There are {} uniques categories.'.format(len(venues_chennai['Venue Category'].unique())))
# Out:
# There are 159 uniques categories.

# %% [markdown]
# # 19. Number of unique restaurants returned for each neighborhood in Chennai

# %%
Chennai_restaurants=venues_chennai[venues_chennai['Venue Category'].str.contains("Restaurant")]
print('There are {} uniques categories.'.format(len(Chennai_restaurants['Venue Category'].unique())))
# Out:
# There are 23 uniques categories.

# %% [markdown]
# # 20. Analyze Each Neighborhood

# %%
# one hot encoding
chennai_onehot = pd.get_dummies(Chennai_restaurants[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
chennai_onehot['Neighbourhood'] = Chennai_restaurants['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [chennai_onehot.columns[-1]] + list(chennai_onehot.columns[:-1])
chennai_onehot = chennai_onehot[fixed_columns]
chennai_grouped = chennai_onehot.groupby('Neighbourhood').mean().reset_index()
chennai_grouped
# Out:
#           Neighbourhood  Afghan Restaurant  Andhra Restaurant  \
# 0            Adambakkam                0.0                0.0
# 1                 Adyar                0.0                0.0
# 2             Alapakkam                0.0                0.0
# 3              Alwarpet                0.0                0.0
# 4       Alwarthirunagar                0.0                0.0
# 5           Aminjikarai                0.0                0.0
# 6            Anna Nagar                0.0                0.0
# 7           Ashok Nagar                0.0                0.0
# 8            Ayanavaram                0.0                0.0
# 9          Besant Nagar                0.0                0.0
# 10              Chepauk                0.0                0.0
# 11              Choolai                0.0                0.0
# 12             Chrompet                0.0                0.0
# 13               Egmore                0.0                0.0
# ...

# %% [markdown]
# # 21. Resulting each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in chennai_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = chennai_grouped[chennai_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adambakkam----
#                        venue  freq
# 0          Indian Restaurant   1.0
# 1          Afghan Restaurant   0.0
# 2  Middle Eastern Restaurant   0.0
# 3            Thai Restaurant   0.0
# 4    South Indian Restaurant   0.0
#
#
# ----Adyar----
#                            venue  freq
# 0              Indian Restaurant  0.60
# 1        North Indian Restaurant  0.13
# 2  Vegetarian / Vegan Restaurant  0.07
# 3               Asian Restaurant  0.07
# 4           Fast Food Restaurant  0.07
#
#
# ----Alapakkam----
#                              venue  freq
# 0             Fast Food Restaurant   0.5
# 1                Indian Restaurant   0.5
# 2                Afghan Restaurant   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4                  Thai Restaurant   0.0
#
#
# ----Alwarpet----
#                   venue  freq
# 0   Japanese Restaurant  0.27
# 1            Restaurant  0.18
# 2       Thai Restaurant  0.09
# 3    Chinese Restaurant  0.09
# ...

# %% [markdown]
# # 22. Defining the return_most_common_venues function

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# # 23. Creating a new dataframe and displaying the top 10 restaurants

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
        
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = chennai_grouped['Neighbourhood']


for ind in np.arange(chennai_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(chennai_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#      Neighbourhood 1st Most Common Venue    2nd Most Common Venue  \
# 0       Adambakkam     Indian Restaurant        Afghan Restaurant
# 1            Adyar     Indian Restaurant  North Indian Restaurant
# 2        Alapakkam  Fast Food Restaurant        Indian Restaurant
# 3         Alwarpet   Japanese Restaurant               Restaurant
# 4  Alwarthirunagar  Fast Food Restaurant        Afghan Restaurant
#
#            3rd Most Common Venue            4th Most Common Venue  \
# 0      Middle Eastern Restaurant                  Thai Restaurant
# 1  Vegetarian / Vegan Restaurant                 Asian Restaurant
# 2              Afghan Restaurant  Molecular Gastronomy Restaurant
# 3                Thai Restaurant               Chinese Restaurant
# 4      Middle Eastern Restaurant                  Thai Restaurant
#
#      5th Most Common Venue    6th Most Common Venue  \
# 0  South Indian Restaurant       Seafood Restaurant
# 1     Fast Food Restaurant       Italian Restaurant
# ...

# %% [markdown]
# # 24.Finding the best K value

# %% [markdown]
# A cluster can be defined as a collection of data points aggregated together based on thier similarities.

# %%
chennai_clustering_testing = chennai_grouped.drop('Neighbourhood', 1)

# %%
from matplotlib import pyplot as plt
cost=[]
scores=[]
for i in range(2, 20):  
    KM = KMeans(n_clusters = i, random_state=0).fit_predict(chennai_clustering_testing)
    score = silhouette_score(chennai_clustering_testing, KM)
    cost.append(KM)
    scores.append(score)

plt.figure(figsize=(20,10))    
plt.plot(range(2,20),scores,'o-',color='g')
plt.xlabel("Value of K")
plt.ylabel("Score")
plt.grid(True)
plt.show()

# %%
opt = np.argmax(scores) 
opt
# Out:
# 15

# %%
kclusters = opt

chennai_clustering_testing = chennai_grouped.drop('Neighbourhood', 1)
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(chennai_clustering_testing)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([ 1,  0, 14, 10,  2,  2, 10,  0,  5,  0,  0, 10,  1,  0,  1,  8, 10,
#        13,  1, 10, 14,  1,  1,  4,  1,  0,  0,  3,  2, 14,  0,  2,  1, 14,
#         9,  7,  5,  3,  1,  7,  4,  1,  0,  1,  5,  4, 12,  1, 14,  1,  4,
#        11,  1,  1,  0,  8,  2,  0, 10,  9,  0,  2,  8, 14,  0,  1,  2,  1,
#        10, 14,  3, 12, 14, 12,  1,  0,  1,  2,  0,  1,  1, 14,  4,  1, 10,
#         4,  1,  0, 13,  2, 10,  6], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
Chennai_merged = Chennai_restaurants

# %%
Chennai_merged = Chennai_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')
Chennai_merged.fillna(0)
Chennai_merged.head()
# Out:
#    Neighbourhood  Neighborhood Latitude  Neighborhood Longitude  \
# 4     Adambakkam              12.982221               80.209121
# 5          Adyar              13.006450               80.257779
# 6          Adyar              13.006450               80.257779
# 8          Adyar              13.006450               80.257779
# 10         Adyar              13.006450               80.257779
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 4                  Bistro       12.983193        80.205020
# 5        Bombay Brassiere       13.006961        80.256419
# 6     Adyar Ananda Bhavan       13.005824        80.257368
# 8   Prems Graama Bhojanam       13.006345        80.253995
# 10             McDonald's       13.006632        80.254255
#
#                    Venue Category  Cluster Labels 1st Most Common Venue  \
# 4               Indian Restaurant               1     Indian Restaurant
# 5         North Indian Restaurant               0     Indian Restaurant
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood, cluster in zip(Chennai_merged['Venue Latitude'],Chennai_merged['Venue Longitude'],Chennai_merged['Neighbourhood'],Chennai_merged['Cluster Labels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# # 25.Analyzing each cluster

# %% [markdown]
# Examining **each clusters** and finding the **best restaurant** to open in each cluster.We have assigned a name to each cluster of the **K-Means**.

# %% [markdown]
# ### Cluster 0

# %%
c0=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 0,Chennai_merged.columns[[0]+[3]+[4]+[5]+list(range(8,Chennai_merged.shape[1]))]]
c0
# Out:
#       Neighbourhood                                       Venue  \
# 5             Adyar                            Bombay Brassiere
# 6             Adyar                         Adyar Ananda Bhavan
# 8             Adyar                       Prems Graama Bhojanam
# 10            Adyar                                  McDonald's
# 12            Adyar                               Hotel Coronet
# 15            Adyar                       Daawat The Kebab Shop
# 16            Adyar                       Rainforest Restaurant
# 19            Adyar                              Hotel Crescent
# 21            Adyar                                      Sigree
# 24            Adyar                                Buhari Hotel
# 25            Adyar                           Daawat Restaurant
# 26            Adyar                                Esthel Hotel
# 28            Adyar                                  Hotel runs
# 29            Adyar                                   Kumarakom
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c0['Venue Latitude'],c0['Venue Longitude'],c0['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 1

# %%
c1=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 1,Chennai_merged.columns[[0]+[3]+[4]+[5]+list(range(8,Chennai_merged.shape[1]))]]
c1
# Out:
#            Neighbourhood                         Venue  Venue Latitude  \
# 4             Adambakkam                        Bistro       12.983193
# 186             Chrompet              Muniyaandi Vilas       12.937959
# 202        Ekkaduthangal                   Andhra mess       13.025395
# 228    Government Estate         Hotel Saravana Bhavan       13.068072
# 266          Injambakkam           Annachi Dosai Kadai       12.914791
# 268       Iyyapanthangal                Akshaya Bhavan       13.039774
# 292           K.K. Nagar                Nambiyar Hotel       11.211436
# 318             Kolathur                     RS Bhavan       13.123988
# 324             Kolathur          Nachiyar rusi-o-rusi       13.122807
# 373          Maduravoyal            Biriyani 'n' Kebab       13.063521
# 390           Manapakkam      Sangeetha Veg Restaurant       13.015420
# 392           Manapakkam                  Hotel Vairam       13.014952
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c1['Venue Latitude'],c1['Venue Longitude'],c1['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='orange',
        fill=True,
        fill_color='orange',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 2

# %%
c2=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 2,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c2
# Out:
#        Neighbourhood             Venue  Venue Latitude  Venue Longitude  \
# 66   Alwarthirunagar               KFC       13.044008        80.184089
# 76       Aminjikarai        McDonald's       13.073759        80.221388
# 84       Aminjikarai               KFC       13.073922        80.221462
# 295     Keelkattalai               KFC       12.953459        80.186612
# 317      Kodungaiyur    Refresh Corner       13.135873        80.242394
# 492          Noombal  hilton fast food       13.053556        80.138654
# 493          Noombal    Pandiyan Hotel       13.057618        80.136755
# 544       Pattabiram  Modern Fast Food       13.121285        80.063143
# 594       Raj Bhavan               KFC       17.422668        78.462377
# 657         Tambaram         Hot Chips       12.928186        80.114355
# 803      Villivakkam    Street Kitchen       13.114557        80.206540
#
#     1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c2['Venue Latitude'],c2['Venue Longitude'],c2['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 3

# %%
c3=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 3,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c3
# Out:
#     Neighbourhood         Venue  Venue Latitude  Venue Longitude  \
# 288   Kazhipattur   Parkway Inn       12.823802        80.230780
# 290   Kazhipattur  Inzy gardens       12.827890        80.230997
# 346   Kotturpuram       Soy Soi       13.019072        80.241380
# 347   Kotturpuram    Savya Rasa       13.019087        80.241341
# 348   Kotturpuram  Krishna cafe       13.018216        80.240983
# 625      Saidapet    Data Udipi       13.020143        80.224863
#
#        1st Most Common Venue    2nd Most Common Venue  \
# 288         Asian Restaurant  South Indian Restaurant
# 290         Asian Restaurant  South Indian Restaurant
# 346         Asian Restaurant  South Indian Restaurant
# 347         Asian Restaurant  South Indian Restaurant
# 348         Asian Restaurant  South Indian Restaurant
# 625  South Indian Restaurant        Afghan Restaurant
#
#          3rd Most Common Venue      4th Most Common Venue  \
# 288          Afghan Restaurant  Middle Eastern Restaurant
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c3['Venue Latitude'],c3['Venue Longitude'],c3['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='purple',
        fill=True,
        fill_color='purple',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 4

# %%
c4=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 4,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c4
# Out:
#        Neighbourhood                       Venue  Venue Latitude  \
# 271    Jafferkhanpet       Hotel Saravana Bhavan       13.029987
# 272    Jafferkhanpet                   PalmShore       13.029631
# 382  Manali New Town                Abhishek Veg       18.503842
# 383  Manali New Town            Purepur Kolhapur       18.504002
# 387  Manali New Town              New China Town       18.499423
# 425        Mogappair              A2B Restaurant       13.080587
# 426        Mogappair          Sree Balaji Bhavan       13.083661
# 461         Mylapore  Mylai Sri Karpagambal Mess       13.032904
# 462         Mylapore       Hotel Saravana Bhavan       13.034448
# 463         Mylapore                   Sangeetha       13.031806
# 725    Tiruvallikeni                  Ratna cafe       13.058740
# 726    Tiruvallikeni              A2B Triplicane       13.058265
# 727    Tiruvallikeni          Kasi Vinayaga Mess       13.060754
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c4['Venue Latitude'],c4['Venue Longitude'],c4['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='grey',
        fill=True,
        fill_color='grey',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 5

# %%
c5=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 5,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c5
# Out:
#     Neighbourhood                                              Venue  \
# 134    Ayanavaram                                         Noor Hotel
# 351        Kottur                               Navaruchi Restaurant
# 412  Meenambakkam  Hotel Virudhunagar - Quality Inn Airport – Che...
#
#      Venue Latitude  Venue Longitude 1st Most Common Venue  \
# 134       13.094934        80.233038            Restaurant
# 351       13.366036        79.088365            Restaurant
# 412       12.985761        80.174250            Restaurant
#
#     2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 134     Afghan Restaurant  Middle Eastern Restaurant       Thai Restaurant
# 351     Afghan Restaurant  Middle Eastern Restaurant       Thai Restaurant
# 412     Afghan Restaurant  Middle Eastern Restaurant       Thai Restaurant
#
#        5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c5['Venue Latitude'],c5['Venue Longitude'],c5['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='yellow',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 6

# %%
c6=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 6,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c6
# Out:
#      Neighbourhood   Venue  Venue Latitude  Venue Longitude  \
# 821  West Mambalam  Manjal       13.045031        80.225209
#
#     1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# 821     Andhra Restaurant     Afghan Restaurant  Middle Eastern Restaurant
#
#     4th Most Common Venue    5th Most Common Venue 6th Most Common Venue  \
# 821       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
#
#     7th Most Common Venue  8th Most Common Venue    9th Most Common Venue  \
# 821            Restaurant  Rajasthani Restaurant  North Indian Restaurant
#
#       10th Most Common Venue
# 821  New American Restaurant

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c6['Venue Latitude'],c6['Venue Longitude'],c6['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 7

# %%
c7=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 7,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c7
# Out:
#     Neighbourhood                          Venue  Venue Latitude  \
# 335   Kottivakkam  Bella Ciao Italian Restorante       12.972193
# 377        Manali                    Rose Garden       32.261903
# 378        Manali                Fuji Restaurant       32.265788
#
#      Venue Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 335        80.264678    Italian Restaurant     Afghan Restaurant
# 377        77.189732    Italian Restaurant   Japanese Restaurant
# 378        77.187688    Italian Restaurant   Japanese Restaurant
#
#          3rd Most Common Venue            4th Most Common Venue  \
# 335  Middle Eastern Restaurant                  Thai Restaurant
# 377          Afghan Restaurant  Molecular Gastronomy Restaurant
# 378          Afghan Restaurant  Molecular Gastronomy Restaurant
#
#        5th Most Common Venue    6th Most Common Venue 7th Most Common Venue  \
# 335  South Indian Restaurant       Seafood Restaurant            Restaurant
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c7['Venue Latitude'],c7['Venue Longitude'],c7['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='pink',
        fill=True,
        fill_color='pink',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 8

# %%
c8=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 8,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c8
# Out:
#     Neighbourhood           Venue  Venue Latitude  Venue Longitude  \
# 205      Eranavur  Wang's Kitchen       13.187471        80.305786
# 491      Nolambur     The Kitchen       13.073680        80.164458
# 557      Perambur   Wangs Kitchen       13.115749        80.245922
#
#     1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# 205    Chinese Restaurant     Afghan Restaurant  Middle Eastern Restaurant
# 491    Chinese Restaurant     Afghan Restaurant  Middle Eastern Restaurant
# 557    Chinese Restaurant     Afghan Restaurant  Middle Eastern Restaurant
#
#     4th Most Common Venue    5th Most Common Venue 6th Most Common Venue  \
# 205       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
# 491       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
# 557       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
#
#     7th Most Common Venue  8th Most Common Venue    9th Most Common Venue  \
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c8['Venue Latitude'],c8['Venue Longitude'],c8['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='silver',
        fill=True,
        fill_color='silver',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 9

# %%
c9=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 9,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c9
# Out:
#     Neighbourhood                  Venue  Venue Latitude  Venue Longitude  \
# 332    Korukkupet   Adayar Ananda Bhavan       13.118110        80.284481
# 333    Korukkupet             Idli Vilas       13.117964        80.285028
# 532     Park Town  Hotel Saravana Bhavan       13.082935        80.275032
#
#              1st Most Common Venue      2nd Most Common Venue  \
# 332  Vegetarian / Vegan Restaurant  Middle Eastern Restaurant
# 333  Vegetarian / Vegan Restaurant  Middle Eastern Restaurant
# 532  Vegetarian / Vegan Restaurant  Middle Eastern Restaurant
#
#     3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 332       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
# 333       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
# 532       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
#
#     6th Most Common Venue  7th Most Common Venue    8th Most Common Venue  \
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c9['Venue Latitude'],c9['Venue Longitude'],c9['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='lightgreen',
        fill=True,
        fill_color='lightgreen',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 10

# %%
c10=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 10,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c10
# Out:
#         Neighbourhood                                    Venue  \
# 45           Alwarpet                           Ashvita Bistro
# 47           Alwarpet                            Ox and Tomato
# 48           Alwarpet                                Benjarong
# 49           Alwarpet                      Teppan At Benjarong
# 54           Alwarpet                                 New Town
# 55           Alwarpet                              GO GO Ramen
# 56           Alwarpet                                 Wonton's
# 58           Alwarpet                                Momo Yama
# 59           Alwarpet                                 Mansuk's
# 60           Alwarpet                                New Seoul
# 61           Alwarpet                       Lakshmi fast foods
# 93         Anna Nagar                        Savoury Sea Shell
# 94         Anna Nagar                             Cream Centre
# 96         Anna Nagar                            Wangs Kitchen
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c10['Venue Latitude'],c10['Venue Longitude'],c10['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='lightblue',
        fill=True,
        fill_color='lightblue',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 11

# %%
c11=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 11,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c11
# Out:
#     Neighbourhood          Venue  Venue Latitude  Venue Longitude  \
# 469      Nandanam  Fuji Restrant       13.030044        80.242301
#
#     1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# 469   Japanese Restaurant     Afghan Restaurant  Middle Eastern Restaurant
#
#     4th Most Common Venue    5th Most Common Venue 6th Most Common Venue  \
# 469       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
#
#     7th Most Common Venue  8th Most Common Venue    9th Most Common Venue  \
# 469            Restaurant  Rajasthani Restaurant  North Indian Restaurant
#
#       10th Most Common Venue
# 469  New American Restaurant

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c11['Venue Latitude'],c11['Venue Longitude'],c11['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='#8DB600',
        fill=True,
        fill_color='#8DB600',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 12

# %%
c12=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 12,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c12
# Out:
#     Neighbourhood                    Venue  Venue Latitude  Venue Longitude  \
# 450    Moolakadai              Glass Store       13.128105        80.245694
# 630    Saligramam  Blue Diamond Food Court       13.058204        80.194859
# 641      Selaiyur          PASSANG KITCHEN       12.915034        80.129005
#
#     1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# 450      Asian Restaurant     Afghan Restaurant  Middle Eastern Restaurant
# 630      Asian Restaurant     Afghan Restaurant  Middle Eastern Restaurant
# 641      Asian Restaurant     Afghan Restaurant  Middle Eastern Restaurant
#
#     4th Most Common Venue    5th Most Common Venue 6th Most Common Venue  \
# 450       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
# 630       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
# 641       Thai Restaurant  South Indian Restaurant    Seafood Restaurant
#
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c12['Venue Latitude'],c12['Venue Longitude'],c12['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='#FBCEB1',
        fill=True,
        fill_color='#FBCEB1',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 13

# %%
c13=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 13,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c13
# Out:
#        Neighbourhood           Venue  Venue Latitude  Venue Longitude  \
# 224      George Town     Hot Chicken       13.096466        80.290364
# 798  Velappanchavadi  Pandiyan Hotel       13.057618        80.136755
# 799  Velappanchavadi          Buhari       13.060711        80.135745
#
#     1st Most Common Venue      2nd Most Common Venue  \
# 224     Afghan Restaurant  Middle Eastern Restaurant
# 798     Afghan Restaurant       Fast Food Restaurant
# 799     Afghan Restaurant       Fast Food Restaurant
#
#          3rd Most Common Venue    4th Most Common Venue  \
# 224            Thai Restaurant  South Indian Restaurant
# 798  Middle Eastern Restaurant          Thai Restaurant
# 799  Middle Eastern Restaurant          Thai Restaurant
#
#        5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 224       Seafood Restaurant            Restaurant  Rajasthani Restaurant
# 798  South Indian Restaurant    Seafood Restaurant             Restaurant
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c13['Venue Latitude'],c13['Venue Longitude'],c13['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='#7FFFD4',
        fill=True,
        fill_color='#7FFFD4',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Cluster 14

# %%
c14=Chennai_merged.loc[Chennai_merged['Cluster Labels'] == 14,Chennai_merged.columns[[0]+[3]+[4]+[5] + list(range(8,Chennai_merged.shape[1]))]]
c14
# Out:
#     Neighbourhood                                   Venue  Venue Latitude  \
# 36      Alapakkam                             Suguna Mess       13.052622
# 37      Alapakkam                          MADC Cafetaria       13.052944
# 260    IIT Madras                                Tifany's       12.990524
# 262    IIT Madras                         IIT Campus Cafe       12.991224
# 302       Kilpauk                              McDonald's       13.083481
# 308       Kilpauk                            Kebab Street       13.080102
# 326      Korattur                        Jeevan Your Cafe       13.109056
# 327      Korattur                          chappati kings       13.113352
# 328      Korattur                                 Sathvik       13.109274
# 329      Korattur                  Thalapa Kattu Biriyani       13.112894
# 433    Mount Road                         Saravana Bhavan       13.061508
# 436    Mount Road                            Kabab Corner       13.060163
# ...

# %%
map_clusters = folium.Map(location=[13.0836939,80.270186],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighbourhood in zip(c14['Venue Latitude'],c14['Venue Longitude'],c14['Neighbourhood']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='#8F9779',
        fill=True,
        fill_color='#8F9779',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# # Result and Discussions

# %%
data1 = [["0","South Indian Restaurant", "Vegetarian / Vegan Restaurant","Asian Restaurant","North Indian Restaurant"], ["1","Fast Food Restaurant", "Afghan Restaurant","Molecular Gastronomy Restaurant","New American Restaurant"],["2","Indian Restaurant","Vegetarian / Vegan Restaurant","North Indian Restaurant","Seafood Restaurant"],["3","Vegetarian / Vegan Restaurant","Asian Restaurant","Thai Restaurant/Molecular Gastronomy Restaurant","New American Restaurant and Multicuisine Indian Restaurant"],["4","Indian Restaurant","Afghan Restaurant","Molecular Gastronomy Restaurant","New American Restaurant"],["5","Indian Restaurant and Restaurant","Afghan Restaurant","Thai Restaurant","Multicuisine Indian Restaurant"],["6","Vegetarian / Vegan Restaurant","Chinese Restaurant","Molecular Gastronomy Restaurant","New American Restaurant"],["7","Asian Restaurant","Afghan Restaurant","Thai Restaurant","Multicuisine Indian Restaurant"],["8","Japanese Restaurant and Middle Eastern Restaurant","Chinese Restaurant and Indian Restaurant","Fast Food Restaurant","Korean Restaurant"],["9","Chinese Restaurant","Indian Restaurant","Italian Restaurant","Rajasthani Restaurant and North Indian Restaurant"],["10","Italian Restaurant","Japanese Restaurant","Afghan Restaurant","North Indian Restaurant"],["11","Chinese Restaurant","Afghan Restaurant","Molecular Gastronomy Restaurant","New American Restaurant"],["12","Afghan Restaurant","Asian Restaurant","Thai Restaurant","Multicuisine Indian Restaurant"],["13","Middle Eastern Restaurant","Rajasthani Restaurant","Asian Restaurant","Multicuisine Indian Restaurant"],["14","Vegetarian / Vegan Restaurant","Multicuisine Indian Restaurant","Asian Restaurant","New American Restaurant"]]
pd.DataFrame(data1, columns=["Cluster", "Most Common Restaurant","2nd Most Common Restaurant","3rd Most Common Restaurant","Least Common Restaurant"])
# Out:
#    Cluster                             Most Common Restaurant  \
# 0        0                            South Indian Restaurant
# 1        1                               Fast Food Restaurant
# 2        2                                  Indian Restaurant
# 3        3                      Vegetarian / Vegan Restaurant
# 4        4                                  Indian Restaurant
# 5        5                   Indian Restaurant and Restaurant
# 6        6                      Vegetarian / Vegan Restaurant
# 7        7                                   Asian Restaurant
# 8        8  Japanese Restaurant and Middle Eastern Restaurant
# 9        9                                 Chinese Restaurant
# 10      10                                 Italian Restaurant
# 11      11                                 Chinese Restaurant
# 12      12                                  Afghan Restaurant
# 13      13                          Middle Eastern Restaurant
# ...

# %% [markdown]
# We can construct the analogy in three ways:
# <ol>
# <li>If we want to start a restaurant by not keeping cuisine in mind, it is better to go for the <strong>least common restaurant</strong> so that it would be different to the customers and also provide a new trend in that area. In this case, We can find out that most of the clusters have <strong>New American Restaurant</strong> to be least, so it can be a trendsetter in a few areas like <strong>Alwarpet</strong> and <strong>Adyar</strong>.</li>
# <li>If we want to start a restaurant by keeping cuisine in mind, then it is better to go for that area which has the <strong>least common restaurant</strong> based on that cuisine so that it would be a change to the customers. For example, if you are <strong>franchise</strong> and looking for which area to start the restaurant, it is better to look over those areas which are least common for that particular cuisine.</li>
# <li>If we want to start a restaurant by keeping cuisine in mind, then they can find out the areas which have <strong>second and third common restaurants</strong> based on that restaurant because there can be cuisine based restaurants which might not be successful, so this can be a <strong>game changer</strong>.</li>
# </ol>

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this project, we have used a **list of areas of Chennai** and its neighborhoods with a variety of restaurants in that neighborhood. For this, we have used **K-Means Clustering** where the neighborhoods are categorized with respect to **top 10 common spots**. Investors can have an idea of what kind of restaurant to be started by analyzing the clustering results. Even though we did not have much information, our future work is to have more features on that type of restaurant in order to have a more optimal model.

# %% [markdown]
# # References

# %% [markdown]
# <ol>
# <li>https://en.wikipedia.org/wiki/Areas_of_Chennai</li>
# <li>https://en.wikipedia.org/wiki/Chennai</li>
# <li>https://developer.foursquare.com/</li>
# <li>https://www.britannica.com/place/Chennai</li>
# <li>https://en.wikipedia.org/wiki/K-means_clustering</li>
# </ol>
